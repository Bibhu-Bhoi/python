# %%
# Out:
# hello world

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.to_csv('output.csv',index = False)

# %%
import pandas as pd
df = pd.read_csv("data.csv")
df.to_csv('output.csv',index = False)
ages = df['AGE']
adult = df[df['AGE']>30]
sorted_df = df.sort_values(by='AGE')
print("Ages in sorted order is \n",sorted_df)
# Out:
# Ages in sorted order is
#            SR.  NAME GENDER   AGE       DATE         COUNTRY
# 96       97.0  Dett   Male  18.0  21/05/2015  Great Britain
# 7488   7489.0  Dett   Male  18.0  21/05/2015  Great Britain
# 0         1.0  Dett   Male  18.0  21/05/2015  Great Britain
# 480     481.0  Dett   Male  18.0  21/05/2015  Great Britain
# 48       49.0  Dett   Male  18.0  21/05/2015  Great Britain
# ...       ...   ...    ...   ...         ...            ...
# 15718     NaN   NaN    NaN   NaN         NaN            NaN
# 15719     NaN   NaN    NaN   NaN         NaN            NaN
# 15720     NaN   NaN    NaN   NaN         NaN            NaN
# 15721     NaN   NaN    NaN   NaN         NaN            NaN
# 15722     NaN   NaN    NaN   NaN         NaN            NaN
#
# [15723 rows x 6 columns]

# %%
import pandas as pd
# Read data from a CSV file
df = pd.read_csv('data.csv')
# Write data to a CSV file
df.to_csv('output.csv', index=False)

# Select a column
ages = df['AGE']
print("index ages\n",ages)
# Filter rows where age is greater than 30
adults = df[df['AGE'] > 30]
print("Adults\n", adults)
# Sort by age
sorted_df = df.sort_values(by='AGE')

# Print sorted DataFrame
print("Sorted by age\n",sorted_df)
# Out:
# index ages
#  0        18.0
# 1        19.0
# 2        20.0
# 3        21.0
# 4        22.0
#          ...
# 15718     NaN
# 15719     NaN
# 15720     NaN
# 15721     NaN
# 15722     NaN
# Name: AGE, Length: 15723, dtype: float64
# Adults
#             SR.     NAME  GENDER   AGE       DATE         COUNTRY
# 13        14.0  Demetas  Female  31.0  15/10/2020  Great Britain
# 14        15.0  Jeromyw  Female  32.0  16/08/2019         France
# 15        16.0   Rashid  Female  33.0  21/05/2018         France
# 16        17.0     Dett  Female  34.0  21/05/2019  United States
# 17        18.0    Nern   Female  35.0  15/10/2021  United States
# ...        ...      ...     ...   ...         ...            ...
# 10665  10612.0  Demetas  Female  63.0  15/10/2028         France
# 10666  10613.0  Jeromyw  Female  64.0  16/08/2027  United States
# 10667  10614.0   Rashid  Female  65.0  21/05/2026  United States
# 10668  10615.0    Nern   Female  35.0  15/10/2021  United States
# 10669  10616.0  Kallsie  Female  36.0  16/08/2020  Great Britain
#
# [8954 rows x 6 columns]
# Sorted by age
#            SR.  NAME GENDER   AGE       DATE         COUNTRY
# 96       97.0  Dett   Male  18.0  21/05/2015  Great Britain
# 7488   7489.0  Dett   Male  18.0  21/05/2015  Great Britain
# 0         1.0  Dett   Male  18.0  21/05/2015  Great Britain
# 480     481.0  Dett   Male  18.0  21/05/2015  Great Britain
# 48       49.0  Dett   Male  18.0  21/05/2015  Great Britain
# ...       ...   ...    ...   ...         ...            ...
# 15718     NaN   NaN    NaN   NaN         NaN            NaN
# 15719     NaN   NaN    NaN   NaN         NaN            NaN
# 15720     NaN   NaN    NaN   NaN         NaN            NaN
# 15721     NaN   NaN    NaN   NaN         NaN            NaN
# 15722     NaN   NaN    NaN   NaN         NaN            NaN
#
# [15723 rows x 6 columns]

# %%
import matplotlib .pyplot as plt
# Data
x = [1, 2, 3, 4, 5]
y = [10, 20, 25, 30, 40]

# Create a plot
plt.plot(x, y)

# Add title and labels
plt.title('Simple Line Plot')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')

# Show the plot
plt.show()
